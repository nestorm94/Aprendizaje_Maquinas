# %% [markdown]
# <a href="https://colab.research.google.com/github/nestorm94/Aprendizaje_Maquinas/blob/main/Ejercicio_validaci%C3%B3n_cruzada_Nestor_Morales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import plot_tree
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

# %%
X = [[2],[4],[1],[3],[5],[7],[8],[10],[12]]
y = ["C1","C0","C0","C1","C0","C0","C1","C1","C0"]

# %%
result = cross_validate(DecisionTreeClassifier(max_depth=1),
                        X, y,cv=3,scoring="accuracy",
                        return_train_score=True,
                        return_estimator=True)

# %%
result
# Out:
# {'fit_time': array([0.00314689, 0.00091743, 0.00083542]),
#  'score_time': array([0.00169468, 0.00073981, 0.00070834]),
#  'estimator': [DecisionTreeClassifier(max_depth=1),
#   DecisionTreeClassifier(max_depth=1),
#   DecisionTreeClassifier(max_depth=1)],
#  'test_score': array([0.33333333, 0.33333333, 0.33333333]),
#  'train_score': array([0.83333333, 0.83333333, 0.66666667])}

# %%
X1 = [[2],[4],[1],[3],[5],[7]]
y1 = ["C1","C0","C0","C1","C0","C0"]
x_Val1 = [[8],[10],[12]]
y_val1 = ["C1","C1","C0"]

X2 = [[2],[4],[1],[8],[10],[12]]
y2 = ["C1","C0","C0","C1","C1","C0"]
x_val2 = [[3],[5],[7]]
y_val2 = ["C1","C0","C0"]

X3 = [[3],[5],[7],[8],[10],[12]]
y3 = ["C1","C0","C0","C1","C1","C0"]
x_val3 =[[2],[4],[1]]
y_val3 = ["C1","C0","C0"]

# %%
modelo = DecisionTreeClassifier(max_depth=1)
modelo2 = DecisionTreeClassifier(max_depth=1)
modelo3 = DecisionTreeClassifier(max_depth=1)

# %%
modelo.fit(X1, y1)
modelo2.fit(X2, y2)
modelo3.fit(X3, y3)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
modelo.predict(x_Val1)
# Out:
# array(['C0', 'C0', 'C0'], dtype='<U2')

# %%
modelo.predict(x_val2)
# Out:
# array(['C1', 'C0', 'C0'], dtype='<U2')

# %%
modelo.predict(x_val3)
# Out:
# array(['C1', 'C0', 'C1'], dtype='<U2')

# %%
plot_tree(modelo)
# Out:
# [Text(0.5, 0.75, 'x[0] <= 3.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.25, 0.25, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]')]

# %%
plot_tree(modelo2)
# Out:
# [Text(0.5, 0.75, 'x[0] <= 1.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.75, 0.25, 'gini = 0.48\nsamples = 5\nvalue = [2, 3]')]

# %%
plot_tree(modelo3)
# Out:
# [Text(0.5, 0.75, 'x[0] <= 4.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.75, 0.25, 'gini = 0.48\nsamples = 5\nvalue = [3, 2]')]
