# %% [markdown]
# <a href="https://colab.research.google.com/github/nestorm94/Aprendizaje_Maquinas/blob/main/Ejercicio_%C3%A1rbol_regresor_mse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

from sklearn.metrics import mean_squared_error
import math
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.tree import plot_tree
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_validate

# %%
#<=20
y_true1 = [2.8,3.0,3.2]
y_ped1 = [3.0,3.0,3.0]
mse_1 = mean_squared_error(y_true1,y_ped1)
mse_1
y_true2 = [4.1,4.2,4.3]
y_ped2 = [4.2,4.2,4.2]
mse_2 = mean_squared_error(y_true2,y_ped2)
mse_2

error_total_20 =(((3/6)*mse_1)+(3/6)*mse_2)
error_total_20
# Out:
# 0.016666666666666698

# %%
#<=17
y_true2 = [2.8]
y_ped2 = [2.8]
mse_3 = mean_squared_error(y_true2,y_ped2)
mse_3
y_true4 = [3.0,3.2,4.1,4.2,4.3]
y_ped4 = [3.76,3.76,3.76,3.76,3.76]
mse_4 = mean_squared_error(y_true4,y_ped4)
mse_4

error_total_17 =(((1/6)*mse_3)+(5/6)*mse_4)
error_total_17
# Out:
# 0.2486666666666666

# %%
#<=19
y_true5 = [2.8,3.0]
y_ped5 = [2.9,2.9]
mse_5 = mean_squared_error(y_true5,y_ped5)
mse_5
y_true6 = [3.2,4.1,4.2,4.3]
y_ped6 = [3.95,3.95,3.95,3.95]
mse_6 = mean_squared_error(y_true6,y_ped6)
mse_6

error_total_19 =(((2/6)*mse_5)+(4/6)*mse_6)
error_total_19
# Out:
# 0.13166666666666657

# %%
#<=22.5
y_true7 = [2.8,3.0,3.2,4.1,4.2]
y_ped7 = [3.46,3.46,3.46,3.46,3.46]
mse_7 = mean_squared_error(y_true7,y_ped7)
mse_7
y_true8 = [4.3]
y_ped8 = [4.3]
mse_8 = mean_squared_error(y_true8,y_ped8)
mse_8

error_total_22 =(((5/6)*mse_7)+(1/6)*mse_7)
error_total_22
# Out:
# 0.33440000000000003

# %%
y_true7 = [2.8,3.0,3.2,4.1,4.2,4.3]
y_ped7 = [3.46,3.46,3.46,3.46,3.46]
mse_7 = mean_squared_error(y_true7,y_ped7)
mse_7
y_true8 = [4.3]
y_ped8 = [4.3]
mse_8 = mean_squared_error(y_true8,y_ped8)
mse_8

error_total_22 =(((5/6)*mse_7)+(1/6)*mse_7)
error_total_22

# %%
edad = [[16],[18],[20],[22],[22],[23]]
notas = [2.8,3.0,3.2,4.1,4.2,4.3]


model = DecisionTreeRegressor(max_depth=1)
model.fit(edad,notas)

plot_tree(model)
# Out:
# [Text(0.5, 0.75, 'x[0] <= 21.0\nsquared_error = 0.377\nsamples = 6\nvalue = 3.6'),
#  Text(0.25, 0.25, 'squared_error = 0.027\nsamples = 3\nvalue = 3.0'),
#  Text(0.75, 0.25, 'squared_error = 0.007\nsamples = 3\nvalue = 4.2')]

# %%
#<=20
y_true_1 = [2.8,3.0]
y_ped_1 = [2.9,2.9]
mse1 = mean_squared_error(y_true_1,y_ped_1)
mse1
y_true_2 = [3.2]
y_ped_2 = [3.2]
mse2 = mean_squared_error(y_true_2,y_ped_2)
mse2

error =(((2/3)*mse1)+(1/3)*mse2)
error
# Out:
# 0.006666666666666678

# %%
edad = [[16],[18],[20]]
notas = [2.8,3.0,3.2]


model = DecisionTreeRegressor(max_depth=2)
model.fit(edad,notas)

plot_tree(model)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[0] <= 17.0\nsquared_error = 0.027\nsamples = 3\nvalue = 3.0'),
#  Text(0.2, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 2.8'),
#  Text(0.6, 0.5, 'x[0] <= 19.0\nsquared_error = 0.01\nsamples = 2\nvalue = 3.1'),
#  Text(0.4, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.8, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 3.2')]
