# %% [markdown]
# <a href="https://colab.research.google.com/github/nestorm94/Aprendizaje_Maquinas/blob/main/ML_25_08_Predict_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.tree import plot_tree
import math
import pandas as pd
import matplotlib.pyplot as plt

# %%
x1 = [1, 5, 3, 6, 9, 0, 4, 5]
x2 = [3, 4, 1, 8, 1, 2, 3, 1]
yR =  [4.3, 2.1, 8.0, 2.5, 3.6, 4.1, 2.3, 0]
yC =  [1, 0, 0, 1, 0, 0, 1, 1]

# %%
model = DecisionTreeRegressor(max_depth=2)
model.fit(list(zip(x1, x2)), yR)

plt.figure(figsize=(10, 6))
plot_tree(model, feature_names=["x1", "x2"] )
plt.show()

# %%
def predict(x1_val, x2_val):
    if x1_val <= 3.5:
        if x2_val <= 1.5:
           return "NodoA"
        else:
          return "nodoB"
    else:
      if x1_val <= 5.5:
        return "NodoC"
      else:
          return "NodoC"


for i in range(len(x1)):
    prediction = predict(x1[i], x2[i])
    print(f"Para x1={x1[i]}, x2={x2[i]}: Clase predicha: {prediction}, Clase real: {y[i]}")


x_1=0
x_2=0
predicion = model.predict([[x_1,x_2]])
prediccion_modelo  = predict(x_1,x_2)
predicion
# Out:
# Para x1=1, x2=3: Clase predicha: nodoB, Clase real: 4.3
# Para x1=5, x2=4: Clase predicha: NodoC, Clase real: 2.1
# Para x1=3, x2=1: Clase predicha: NodoA, Clase real: 8.0
# Para x1=6, x2=8: Clase predicha: NodoC, Clase real: 2.5
# Para x1=9, x2=1: Clase predicha: NodoC, Clase real: 3.6
# Para x1=0, x2=2: Clase predicha: nodoB, Clase real: 4.1
# Para x1=4, x2=3: Clase predicha: NodoC, Clase real: 2.3
# Para x1=5, x2=1: Clase predicha: NodoC, Clase real: 0
# array([4.2])

# %%
model = DecisionTreeClassifier(max_depth=2)
model.fit(list(zip(x1, x2)), yC)

plt.figure(figsize=(10, 6))
plot_tree(model, feature_names=["x1", "x2"] )
plt.show()

# %%
def predict(x1_val, x2_val):
    if x1_val <= 3.5:
        if x2_val <= 1.5:
           return "NodoA"
        else:
          return "nodoB"
    else:
      if x1_val <= 5.5:
        return "NodoC"
      else:
          return "NodoC"


for i in range(len(x1)):
    prediction = predict(x1[i], x2[i])
    print(f"Para x1={x1[i]}, x2={x2[i]}: Clase predicha: {prediction}, Clase real: {y[i]}")



predicion = predict(0,0)
print(predicion)
# Out:
# Para x1=1, x2=3: Clase predicha: nodoB, Clase real: 4.3
# Para x1=5, x2=4: Clase predicha: NodoC, Clase real: 2.1
# Para x1=3, x2=1: Clase predicha: NodoA, Clase real: 8.0
# Para x1=6, x2=8: Clase predicha: NodoC, Clase real: 2.5
# Para x1=9, x2=1: Clase predicha: NodoC, Clase real: 3.6
# Para x1=0, x2=2: Clase predicha: nodoB, Clase real: 4.1
# Para x1=4, x2=3: Clase predicha: NodoC, Clase real: 2.3
# Para x1=5, x2=1: Clase predicha: NodoC, Clase real: 0
# NodoA
